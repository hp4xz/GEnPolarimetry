# %%
from functions import MakeTime, MakeFullData, Fit, Spinup

import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from sklearn.linear_model import LinearRegression
import scipy.stats as stats
from datetime import datetime

data=np.transpose(np.loadtxt('Spinup1Fringe.txt'))

#t=MakeTime(data)[0]
pc=MakeFullData(data)[1]
tcUP=MakeFullData(data)[2]
tcDOWN=MakeFullData(data)[3]

# %%
data[4]
# Out:
# array([ 0.2223,  7.6803,  0.    ,  9.7806,  6.5645,  0.1054, -8.8041,
#         8.0712,  0.1099,  0.2532, -8.2042,  5.9278,  0.3139,  3.9192,
#        10.2674,  8.6626,  4.556 ,  9.8958,  4.6672,  9.0439,  4.3253,
#         0.1872,  0.6184,  4.078 ,  8.7857,  4.866 , 10.4852, -6.6505,
#         0.1068])

# %%
plt.plot(data[4])
