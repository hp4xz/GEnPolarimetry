# %%
from functions import MakeTime, MakeFullData, Fit, Spinup

import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from sklearn.linear_model import LinearRegression
import scipy.stats as stats

data=np.loadtxt('hunter.txt')
fcut=0
bcut=89
t=MakeTime(data[fcut:bcut])[0]
pc=MakeFullData(data[fcut:bcut])[0]
tcUP=MakeFullData(data[fcut:bcut])[1]
tcDOWN=MakeFullData(data[fcut:bcut])[2]

# %%
t=np.arange(0,len(pc),1)

# %%
plt.plot(t,tcDOWN,'.')
plt.ylim(0,5)
# Out:
# (0.0, 5.0)

# %%
pcnew=pc[pc<.5]
pcnew[6]=.12
pcnew=np.delete(pcnew,[0,1])
tnew=np.arange(0,len(pcnew),1)

# %%
plt.plot(tnew,pcnew,'.')

# %%
tct=np.arange(0,len(tcUP),1)
plt.plot(tct,tcUP,'.')
