# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.loadtxt('const.dat')
data=np.transpose(data)

# %%
data
# Out:
# array([[15.560625  , 17.173125  , 18.80175   ],
#        [ 1.40026412,  1.41074301,  1.4427753 ]])

# %%
x = np.arange(0,3)
ratio=np.divide(data[0],data[1])

# %%
plt.plot(x,data[0],'.')
plt.plot(x,data[1]*10,'.')

# %%
plt.plot(x,ratio)
