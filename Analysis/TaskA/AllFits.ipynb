# %%
import sys
import os
sys.path.append(sys.path[0]+'/../../')
sys.path.append(sys.path[0]+'/../NMRDataFits/')
from functions import *
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from math import *
from datetime import datetime
from brokenaxes import brokenaxes

# %%
fits=np.load(sys.path[0]+'/../NMRDataFits/FitsInRange.npy')

# %%
plt.plot(fits[1][np.where(fits[1]<20)],'.')
